# %%
import requests

# %%
url = "https://mykdrama.co/drama/hellbound/"

response = requests.get(url)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="https://www.w3.org/1999/xhtml" lang="fr-FR">
# <head profile="http://gmpg.org/xfn/11">
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="viewport" content="width=device-width" />
# <meta name="theme-color" content="#b360dd">
# <meta name="msapplication-navbutton-color" content="#b360dd">
# <meta name="apple-mobile-web-app-status-bar-style" content="#b360dd">
# <meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v18.3 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>Hellbound - MyKdrama Vostfr | Drama Coréen en Streaming Francais</title>
# 	<meta name="description" content="Regarder Hellbound vostfr, Hellbound en streaming vostfr, mykdrama vostfr, Hellbound gratuit, Hellbound en français, télécharger Hellbound" />
# 	<link rel="canonical" href="https://mykdrama.co/drama/hellbound/" />
# ...
